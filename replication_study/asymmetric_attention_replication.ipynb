# %% [markdown]
# # Asymmetric Attention and Stock Return (Cziraki, Mondria, Wu, 2021)
# > Replication Study by Victor(JingFeng Xiao)

# %%
import pyreadstat
import pandas as pd

# %%
dta_file = './dataset_output05_2018.dta'
df = pd.read_stata(dta_file)

# %%
df.head()
# Out:
#    quarterly    monthly   permno       date  permco  bidlo      askhi  \
# 0 2010-10-01 2010-11-01  50906.0 2010-11-30  2902.0  12.67  12.720000
# 1 2009-07-01 2009-09-01  50906.0 2009-09-30  2902.0   7.69   8.880000
# 2 2008-07-01 2008-09-01  50906.0 2008-09-30  2902.0   8.26  10.250000
# 3 2006-10-01 2006-12-01  50906.0 2006-12-29  2902.0  13.60  15.050000
# 4 2007-07-01 2007-08-01  50906.0 2007-08-31  2902.0  15.48  19.280001
#
#          prc       vol        ret  ...  PercentPriceImpact_LR_Ave  \
# 0  12.720000  188804.0   0.236412  ...                   0.000135
# 1   8.340000  582923.0  -1.997651  ...                   0.000815
# 2   8.450000  660769.0 -17.560977  ...                   0.000852
# 3  14.530000  514585.0   5.366206  ...                   0.000315
# 4  18.299999  461385.0  -2.086684  ...                   0.000507
#
#    PercentPriceImpact_EMO_Ave  PercentPriceImpact_CLNV_Ave  \
# 0                    0.000141                     0.000140
# ...

# %%
df.filter(items=['l_local_searches', 'l_us_searches', 'l_local_searches'])
df.mean()
# Out:
# C:\Users\ConquerV\AppData\Local\Temp/ipykernel_9972/4103422578.py:2: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   df.mean()
# C:\Users\ConquerV\AppData\Local\Temp/ipykernel_9972/4103422578.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean()
# permno                        56510.189730
# permco                        20754.928943
# bidlo                           251.182924
# askhi                           269.412392
# prc                             261.916855
#                                   ...
# PercentPriceImpact_EMO_SW         0.000290
# PercentPriceImpact_EMO_DW         0.000290
# PercentPriceImpact_CLNV_SW        0.000327
# PercentPriceImpact_CLNV_DW        0.000327
# ...
